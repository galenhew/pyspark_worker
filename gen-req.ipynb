# %% [markdown]
# https://necromuralist.github.io/posts/pip-tools-and-pipdeptree/

# %% [markdown]
# get requirements

# %%
1pipdeptree

# %%
# !pipdeptree --freeze | wc -l

# %%
# !pipdeptree --freeze | grep --only-matching --perl-regexp "^[\w\-]+" | grep --invert-match "\-e\|pkg"

# %%
# generate requirements.in
# requirements better than freeze, as generate pacakge without version. can update versions later.

# !pipdeptree --freeze | grep --only-matching --perl-regexp "^[\w\-]+" | grep --invert-match "\-e\|pkg" > requirements.in

# %%
# so can use pip-compile to generate requirements.txt from requirements.in
# !pip install pip-tools

# %%
# !pip-compile | head

# %% [markdown]
# sync to latest package versions

# %%
#pip-tools also installed a command called pip-sync which will keep you in sync with what is in the requirements file,

# %%
# !pip-sync

# %%
# !pip-compile --upgrade

# %%
# !pip-sync
